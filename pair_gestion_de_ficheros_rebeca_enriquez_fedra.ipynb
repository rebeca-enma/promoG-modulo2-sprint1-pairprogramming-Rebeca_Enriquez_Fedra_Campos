# %% [markdown]
# # Pair programming Gestión de Ficheros

# %% [markdown]
# 1. Hacer las importaciones necesarias para abrir un archivo de tipo "csv" en Pandas.
# 2. Abrir el archivo, creando un Dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".
# 3. Guardar el Dataframe en formato Excel y después crear un Dataframe con el Excel. ¿EL Dataframe es similar al que teníais antes?
# 4. Crear una carpeta llamada Files y guardar el mismo archivo en esa carpeta en formato csv .
# 5. Copia el archivo personal.json en la carpeta Files.
# 6. Abre el json y haz las modificaciones necesarias para poder abrirlo correctamente en Pandas.
# 7. Guardar el json modifiado y abrirlo en Pandas para que tenga formato de tabla.

# %%
#Ejercicio 1 

import pandas as pd

# %%
#Ejercicio 2

dt_videogames = pd.read_csv("videogames.csv", index_col = 0)

# %%
dt_videogames
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# ...

# %%
#Ejercicio 3
dt_videogames.to_excel("videogames.xlsx")

# %%
dt_videogames_excel = pd.read_excel("videogames.xlsx", index_col = 0)

# %%
dt_videogames_excel
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# ...

# %%
#Ejercicio 4

df_videogames_excel = pd.read_excel("videogames.xlsx", index_col = 0)

# %%
dt_videogames.to_csv("files/videogames.csv")

# %%
import json

# %%
#Ejercicio 5

with open ("../../../mod-2/personal.json","r") as fichero:
    personal_copia = json.load(fichero)

# %%
with open("files/personal_copia.json", "w") as fichero:
    json.dump(personal_copia, fichero)

# %%
#Ejercicio 6

with open ("files/personal_copia.json","r") as fichero:
    personal_copia = json.load(fichero)

# %%
personal_copia
# Out:
# {'workers': [{'nombre': 'Ana',
#    'edad': 34,
#    'experiencia': 5,
#    'nivel': 'Senior',
#    'salario': 50000,
#    'mascota': 'gatos'},
#   {'nombre': 'Eva',
#    'edad': 37,
#    'experiencia': 2,
#    'nivel': 'Mid',
#    'salario': 35000},
#   {'nombre': 'Marta',
#    'edad': 27,
#    'experiencia': 1,
#    'nivel': 'Junior',
#    'salario': 25000},
#   {'nombre': 'Paula',
#    'edad': 30,
#    'experiencia': 3,
#    'nivel': 'Mid',
#    'salario': 35000}]}

# %%
trabajadores = list(personal_copia.values())
primera_posicion = trabajadores[0]
print(primera_posicion)
# Out:
# [{'nombre': 'Ana', 'edad': 34, 'experiencia': 5, 'nivel': 'Senior', 'salario': 50000, 'mascota': 'gatos'}, {'nombre': 'Eva', 'edad': 37, 'experiencia': 2, 'nivel': 'Mid', 'salario': 35000}, {'nombre': 'Marta', 'edad': 27, 'experiencia': 1, 'nivel': 'Junior', 'salario': 25000}, {'nombre': 'Paula', 'edad': 30, 'experiencia': 3, 'nivel': 'Mid', 'salario': 35000}]

# %%
with open("files/personal_copia.json", "w") as fichero:
    json.dump(primera_posicion, fichero)

# %%
#Ejercicio 7

# %%
df_panda = pd.read_json("files/personal_copia.json")

# %%
df_panda
# Out:
#   nombre  edad  experiencia   nivel  salario mascota
# 0    Ana    34            5  Senior    50000   gatos
# 1    Eva    37            2     Mid    35000     NaN
# 2  Marta    27            1  Junior    25000     NaN
# 3  Paula    30            3     Mid    35000     NaN
